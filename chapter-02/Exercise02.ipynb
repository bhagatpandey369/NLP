# %% [markdown]
# # Exercise 2: Vocabulary Builder
#
# ## Objective
# Find all unique words in a corpus.
#
# ## Input
#
# ```python
# corpus = [
#     "I like NLP",
#     "I like AI",
#     "AI is amazing"
# ]
# ```
#
# ## Expected Output
#
# ```text
# Vocabulary
#
# AI
# I
# NLP
# amazing
# is
# like
#
# Vocabulary Size = 6
# ```
#
# ## Tasks
#
# - Read every sentence in the corpus.
# - Split each sentence into words.
# - Create a vocabulary using a `set`.
# - Print all unique words.
# - Print the vocabulary size.
#
# ## Concepts Learned
#
# - Vocabulary
# - Unique Words
# - Sets
# - Strings
# - Lists

# %%
class VocabularyBuilder:

    def __init__(self, corpus):
        self.corpus = corpus
